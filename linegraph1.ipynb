# %%
import matplotlib.pyplot as plt
x=[1,2,5,7,9]
y=[1,5,6,9,10]
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.xlim(1,10)
plt.ylim(5,10)
plt.title("LINE PLOT")
plt.plot(x,y)
plt.savefig("sample.png")
plt.show()
